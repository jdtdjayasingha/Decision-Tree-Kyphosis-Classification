# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Addition

# %% [markdown]
# ### Add 2 numbers using python

# %%
print(25+10)
# Out:
# 35

# %% [markdown]
# ### Add 3 numbers using python

# %%
print(30+20+15)
# Out:
# 65
